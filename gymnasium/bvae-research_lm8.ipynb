# %%
import tensorflow as tf
import pandas as pd
import numpy as np

# %%
# PARAMETERS
INPUT_HEIGHT = 128
INPUT_WIDTH = 128

INPUT_SHAPE = (INPUT_HEIGHT, INPUT_WIDTH, 1)

latent_dims = 8

# %%
class Preprocessor(tf.keras.Model):
  def __init__(self):
    super().__init__(name="preprocessor")
    self.resizer = tf.keras.layers.Resizing(INPUT_HEIGHT, INPUT_WIDTH, name=f"{self.name}_resizer")
    self.rescaler = tf.keras.layers.Rescaling(scale=1./255, name=f"{self.name}_rescaler")

  def call(self, inputs):
    return self.rescaler(
        self.resizer(inputs)
    )

# %%
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Lambda, Reshape, Conv2DTranspose, BatchNormalization

# %%
class Encoder(tf.keras.layers.Layer):
  def __init__(self, latent_dims):
    super().__init__(name="encoder")

    self.latent_dims = latent_dims

    # layers
    self.preprocess = Preprocessor()
    # 128 x 128 x 1
    self.conv1 = Conv2D(filters=128, kernel_size=3, strides=1, padding='same', activation='relu', name='encoder_conv1')
    self.bnorm1 = BatchNormalization(name="encoder_bnorm1")
    self.mpool1 = MaxPool2D(name='encoder_mpool1')

    # 64 x 64 x 128
    self.conv2 = Conv2D(filters=64, kernel_size=3, strides=1, padding='same', activation='relu', name='encoder_conv2')
    self.bnorm2 = BatchNormalization(name="encoder_bnorm2")
    self.mpool2 = MaxPool2D(name='encoder_mpool2')

    # 32 x 32 x 64
    self.conv3 = Conv2D(filters=32, kernel_size=3, strides=1, padding='same', activation='relu', name='encoder_conv3')
    self.bnorm3 = BatchNormalization(name="encoder_bnorm3")
    self.mpool3 = MaxPool2D(name='encoder_mpool3')

    # 16 x 16 x 32
    self.conv4 = Conv2D(filters=16, kernel_size=3, strides=1, padding='same', activation='relu', name='encoder_conv4')
    self.bnorm4 = BatchNormalization(name="encoder_bnorm4")
    self.mpool4 = MaxPool2D(name='encoder_mpool4')

    # 8 x 8 x 16
    self.flatten = Flatten(name='encoder_flatten')

    self.dense1 = Dense(2 * self.latent_dims, name='encoder_dense1')
    # 2 x self.latent_dims


    self.logvar = Dense(self.latent_dims, name='encoder_logvar')
    self.mu = Dense(self.latent_dims, name='encoder_mu')
    self.sigma = Lambda(lambda x: tf.exp(0.5*x), name='encoder_sigma')

  def encode(self, inputs, preprocess=True):
    # print the shape of the input
    # print(f"Shape of input to encoder: {inputs.shape}")
    p = self.preprocess(inputs) if preprocess else inputs
    x=self.conv1(p); x=self.bnorm1(x); x=self.mpool1(x)
    x=self.conv2(x); x=self.bnorm2(x);  x=self.mpool2(x)
    x=self.conv3(x); x=self.bnorm3(x);  x=self.mpool3(x)
    x=self.conv4(x); x=self.bnorm4(x);  x=self.mpool4(x)
    x=self.flatten(x)
    x=self.dense1(x)
    # print(f"Shape of output from encoder: {x.shape}")

    return self.mu(x), self.logvar(x), self.sigma(self.logvar(x)), p


  def call(self, inputs):
    return self.encode(inputs)

  def summary(self, input_shape):
    x = tf.keras.layers.Input(shape=input_shape)
    model = tf.keras.Model(inputs=[x], outputs=self.call(x))
    return model.summary()

# %%
class Decoder(tf.keras.Model):
    def __init__(self, latent_dims):
        super().__init__(name='decoder')

        self.latent_dims = latent_dims

        # layers
        self.dense1 = Dense(8 * 8 * 16, activation='relu', name='decoder_dense1')
        self.reshape1 = Reshape((8, 8, 16), name='decoder_reshape1')

        # 8 x 8 x 16 -> 16 x 16 x 32
        self.convT1 = Conv2DTranspose(filters=16, kernel_size=3, strides=2, padding='same', activation='relu', name='decoder_convT1')
        self.bnorm1 = BatchNormalization(name="decoder_bnorm1")

        # 16 x 16 x 32 -> 32 x 32 x 64
        self.convT2 = Conv2DTranspose(filters=32, kernel_size=3, strides=2, padding='same', activation='relu', name='decoder_convT2')
        self.bnorm2 = BatchNormalization(name="decoder_bnorm2")

        # 32 x 32 x 64 -> 64 x 64 x 128
        self.convT3 = Conv2DTranspose(filters=64, kernel_size=3, strides=2, padding='same', activation='relu', name='decoder_convT3')
        self.bnorm3 = BatchNormalization(name="decoder_bnorm3")

        # 64 x 64 x 128 -> 128 x 128 x 1
        self.convT4 = Conv2DTranspose(filters=128, kernel_size=3, strides=2, padding='same', activation='relu', name='decoder_convT4')
        self.bnorm4 = BatchNormalization(name="decoder_bnorm4")

        self.output_layer = Conv2D(filters=1, kernel_size=3, strides=1, padding='same', activation='sigmoid', name='decoder_output')

    def decode(self, z):
        x = self.dense1(z)
        x = self.reshape1(x)

        x = self.convT1(x)
        x = self.bnorm1(x)

        x = self.convT2(x)
        x = self.bnorm2(x)

        x = self.convT3(x)
        x = self.bnorm3(x)

        x = self.convT4(x)
        x = self.bnorm4(x)

        return self.output_layer(x)

    def call(self, inputs):
        return self.decode(inputs)

    def summary(self, input_shape):
        x = tf.keras.layers.Input(shape=input_shape)
        model = tf.keras.Model(inputs=[x], outputs=self.call(x))
        return model.summary()

# %%
encoder = Encoder(latent_dims=latent_dims) # Example latent_dims
print("Encoder Summary:")
encoder.summary(input_shape=INPUT_SHAPE)

decoder = Decoder(latent_dims=latent_dims)
print("\nDecoder Summary:")
decoder.summary(input_shape=(latent_dims,))
# Out:
# Encoder Summary:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_4             │ (None, 128, 128, 1)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ preprocessor              │ (None, 128, 128, 1)    │              0 │ input_layer_4[0][0]    │
# │ (Preprocessor)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ encoder_conv1 (Conv2D)    │ (None, 128, 128, 128)  │          1,280 │ preprocessor[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ encoder_bnorm1            │ (None, 128, 128, 128)  │            512 │ encoder_conv1[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ encoder_mpool1            │ (None, 64, 64, 128)    │              0 │ encoder_bnorm1[0][0]   │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ encoder_conv2 (Conv2D)    │ (None, 64, 64, 64)     │         73,792 │ encoder_mpool1[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ encoder_bnorm2            │ (None, 64, 64, 64)     │            256 │ encoder_conv2[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ encoder_mpool2            │ (None, 32, 32, 64)     │              0 │ encoder_bnorm2[0][0]   │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ encoder_conv3 (Conv2D)    │ (None, 32, 32, 32)     │         18,464 │ encoder_mpool2[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ encoder_bnorm3            │ (None, 32, 32, 32)     │            128 │ encoder_conv3[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ encoder_mpool3            │ (None, 16, 16, 32)     │              0 │ encoder_bnorm3[0][0]   │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ encoder_conv4 (Conv2D)    │ (None, 16, 16, 16)     │          4,624 │ encoder_mpool3[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ encoder_bnorm4            │ (None, 16, 16, 16)     │             64 │ encoder_conv4[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ encoder_mpool4            │ (None, 8, 8, 16)       │              0 │ encoder_bnorm4[0][0]   │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ encoder_flatten (Flatten) │ (None, 1024)           │              0 │ encoder_mpool4[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ encoder_dense1 (Dense)    │ (None, 16)             │         16,400 │ encoder_flatten[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ encoder_logvar (Dense)    │ (None, 8)              │            136 │ encoder_dense1[0][0],  │
# │                           │                        │                │ encoder_dense1[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ encoder_mu (Dense)        │ (None, 8)              │            136 │ encoder_dense1[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ encoder_sigma (Lambda)    │ (None, 8)              │              0 │ encoder_logvar[1][0]   │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 115,792 (452.31 KB)
#  Trainable params: 115,312 (450.44 KB)
#  Non-trainable params: 480 (1.88 KB)
# Decoder Summary:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)           │ (None, 8)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ decoder_dense1 (Dense)               │ (None, 1024)                │           9,216 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ decoder_reshape1 (Reshape)           │ (None, 8, 8, 16)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ decoder_convT1 (Conv2DTranspose)     │ (None, 16, 16, 16)          │           2,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ decoder_bnorm1 (BatchNormalization)  │ (None, 16, 16, 16)          │              64 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ decoder_convT2 (Conv2DTranspose)     │ (None, 32, 32, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ decoder_bnorm2 (BatchNormalization)  │ (None, 32, 32, 32)          │             128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ decoder_convT3 (Conv2DTranspose)     │ (None, 64, 64, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ decoder_bnorm3 (BatchNormalization)  │ (None, 64, 64, 64)          │             256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ decoder_convT4 (Conv2DTranspose)     │ (None, 128, 128, 128)       │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ decoder_bnorm4 (BatchNormalization)  │ (None, 128, 128, 128)       │             512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ decoder_output (Conv2D)              │ (None, 128, 128, 1)         │           1,153 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 110,641 (432.19 KB)
#  Trainable params: 110,161 (430.32 KB)
#  Non-trainable params: 480 (1.88 KB)

# %%
class ReconstructionLoss(tf.keras.layers.Layer):
  def __init__(self):
    super(ReconstructionLoss, self).__init__(name="reconstruction_loss")

  def call(self, inputs):
    x = inputs[0]
    recon_x = inputs[1]

    recon_loss = tf.reduce_sum(tf.keras.losses.binary_crossentropy(x, recon_x), axis=[1,2])
    recon_loss = tf.reduce_mean(recon_loss)

    self.add_loss(recon_loss)

    return recon_loss

# %%
class KLLoss(tf.keras.layers.Layer):
  def __init__(self, beta=2.0):
    super(KLLoss, self).__init__()

    self.beta = beta

  def call(self, inputs):
    mu = inputs[0]
    logvar = inputs[1]

    kl_loss = -0.5 * tf.reduce_sum(1 + logvar - tf.square(mu) - tf.exp(logvar), axis=1)
    kl_loss = kl_loss * self.beta

    self.add_loss(kl_loss)
    return kl_loss

# %%
# Sampler

class Sampler(tf.keras.layers.Layer):
  def __init__(self):
    super().__init__(name="sampler")

  def call(self, inputs):
    mu = inputs[0]
    sigma = inputs[1]

    batch = tf.shape(mu)[0]
    dim = tf.shape(mu)[1]
    epsilon = tf.random.normal(shape=(batch, dim))

    # reparameterize
    output =  mu + tf.multiply(sigma, epsilon)

    # print(f"Shape of output from sampler: {output.shape}")
    return output

# %%
class BVAE(tf.keras.Model):
  def __init__(self, latent_dims):
    super().__init__(name="bvae")

    self.latent_dims = latent_dims

    # layers
    self.encoder = Encoder(self.latent_dims)
    self.decoder = Decoder(self.latent_dims)

    self.sampler = Sampler()

    self.reconstruction_loss = ReconstructionLoss()
    self.kl_loss = KLLoss(beta=4.0)

    # trackers
    self.loss_tracker = tf.keras.metrics.Mean(name="loss")
    self.reconstruction_loss_tracker = tf.keras.metrics.Mean(name="reconstruction_loss")
    self.kl_loss_tracker = tf.keras.metrics.Mean(name="kl_loss")

  def call(self, inputs):
    mu, logvar, sigma, x = self.encoder(inputs)
    z = self.sampler([mu, sigma])
    # print(f"Shape of z: {z.shape}")
    recon_x = self.decoder(z)

    kl_loss = self.kl_loss([mu, logvar])
    reconstruction_loss = self.reconstruction_loss([x, recon_x])

    return recon_x, kl_loss, reconstruction_loss

  @property
  def metrics(self):
      return [
          self.loss_tracker,
          self.reconstruction_loss_tracker,
          self.kl_loss_tracker,
      ]

  def train_step(self, data):
    # print(f"Shape of input data in train_step: {data.shape}")

    with tf.GradientTape() as tape:
      recon_x, kl_loss, reconstruction_loss = self(data)
      total_loss = reconstruction_loss + kl_loss

      # update the trackers
      self.loss_tracker.update_state(total_loss)
      self.reconstruction_loss_tracker.update_state(reconstruction_loss)
      self.kl_loss_tracker.update_state(kl_loss)

      # gradients
      grads = tape.gradient(total_loss, self.trainable_weights)
      self.optimizer.apply_gradients(zip(grads, self.trainable_weights))

    return {
        m.name: m.result() for m in self.metrics
    }

  def test_step(self, data):
    recon_x, kl_loss, reconstruction_loss = self(data)
    total_loss = reconstruction_loss + kl_loss
    self.loss_tracker.update_state(total_loss)
    self.reconstruction_loss_tracker.update_state(reconstruction_loss)
    self.kl_loss_tracker.update_state(kl_loss)
    return {
        m.name: m.result() for m in self.metrics
    }

  def encode(self, inputs, preprocess=True):
    return self.encoder.encode(inputs, preprocess=preprocess)

  def decode(self, inputs):
    return self.decoder.decode(inputs)

  def sample(self, mu, sigma):
    return self.sampler([mu, sigma])

  def calculate_reconstruction_loss(self, inputs):
    return self.reconstruction_loss(inputs)

  def calculate_kl_loss(self, inputs):
    return self.kl_loss(inputs)

# %%
class BetaVaeParameterUpdater(tf.keras.callbacks.Callback):
  def __init__(self, delta, limit):
    super().__init__()
    self.delta = delta
    self.limit = limit

  @tf.function
  def update_beta(self):
    beta = self.model.kl_loss.beta
    beta = tf.math.maximum(beta - self.delta, self.limit)

  def on_epoch_end(self, epoch, logs=None):
    self.update_beta()

# %%
images_path = "/kaggle/input/image-data/images"

# %%
model = BVAE(latent_dims=latent_dims)
print("latent_dims:", latent_dims)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3))
# Out:
# latent_dims: 8

# %%
dummy_input = tf.zeros((1, INPUT_HEIGHT, INPUT_WIDTH, 1))
model(dummy_input)
model.summary()
# Out:
# Model: "bvae"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ encoder (Encoder)                    │ ?                           │         115,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ decoder (Decoder)                    │ ?                           │         110,641 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ sampler (Sampler)                    │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reconstruction_loss                  │ ?                           │               0 │
# │ (ReconstructionLoss)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ kl_loss_2 (KLLoss)                   │ ?                           │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 226,433 (884.50 KB)
#  Trainable params: 225,473 (880.75 KB)
#  Non-trainable params: 960 (3.75 KB)

# %%
images = tf.keras.utils.image_dataset_from_directory(
    images_path,
    labels=None,
    color_mode='grayscale',
    image_size=(128, 128),
    batch_size=16,
    shuffle=True, # Ensure shuffling for random split
    seed=42 # Optional: Set seed for reproducible split
)

# clamp the values using threshold and ivnert the color
images = images.map(lambda x:255 - tf.clip_by_value(x, 0, 255))



# Calculate the size of the dataset
dataset_size = tf.data.experimental.cardinality(images).numpy()

train_size = int(0.8 * dataset_size)
test_size = dataset_size - train_size

# Split the dataset using take and skip
train_ds = images.take(train_size)
test_ds = images.skip(train_size)
# Out:
# Found 1899 files.

# %%
# prompt: plot part of the dataset

import matplotlib.pyplot as plt

# Take the first batch from the training dataset
for batch in train_ds.take(1):
    # The batch is a tensor of images
    images_batch = batch

# Select a few images from the batch to plot
num_images_to_plot = 5
plt.figure(figsize=(10, 2))
for i in range(num_images_to_plot):
    plt.subplot(1, num_images_to_plot, i + 1)
    # Squeeze to remove the channel dimension for grayscale images if needed for plotting
    plt.imshow(tf.squeeze(images_batch[i]).numpy(), cmap='gray')
    plt.axis('off')
plt.suptitle('Sample Training Images')
plt.show()

# Take the first batch from the testing dataset
for batch in test_ds.take(1):
    # The batch is a tensor of images
    images_batch = batch

# Select a few images from the batch to plot
plt.figure(figsize=(10, 2))
for i in range(num_images_to_plot):
    plt.subplot(1, num_images_to_plot, i + 1)
    # Squeeze to remove the channel dimension for grayscale images if needed for plotting
    plt.imshow(tf.squeeze(images_batch[i]).numpy(), cmap='gray')
    plt.axis('off')
plt.suptitle('Sample Testing Images')
plt.show()

# %%
import matplotlib.pyplot as plt

beta_updater_callback = BetaVaeParameterUpdater(delta=2e-4, limit=0.0) # Example values

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                                     patience=50,
                                                     cooldown=25,
                                                     min_lr=1e-5,
                                                     min_delta=1.0,
                                                     verbose=1)

early_stop_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                                           patience=50,
                                                           restore_best_weights=True,
                                                           min_delta=1.0,
                                                           verbose=1)
terminate_on_nan = tf.keras.callbacks.TerminateOnNaN()

history = model.fit(
    train_ds,
    epochs=1000, # Adjust the number of epochs as needed
    validation_data=test_ds,
    callbacks=[beta_updater_callback, early_stop_callback] # Add the callback
)

# Plot training history (optional)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# Epoch 1/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 22s 76ms/step - kl_loss: 182.4999 - loss: 8605.7109 - reconstruction_loss: 8423.2100 - val_kl_loss: 89.5176 - val_loss: 1576.6010 - val_reconstruction_loss: 1492.3627
# Epoch 2/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - kl_loss: 92.7708 - loss: 1450.3816 - reconstruction_loss: 1357.6111 - val_kl_loss: 108.6263 - val_loss: 1286.4449 - val_reconstruction_loss: 1181.4493
# Epoch 3/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 95.6354 - loss: 1169.1163 - reconstruction_loss: 1073.4810 - val_kl_loss: 102.9521 - val_loss: 1106.6873 - val_reconstruction_loss: 1005.0488
# Epoch 4/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 91.7995 - loss: 1026.6790 - reconstruction_loss: 934.8796 - val_kl_loss: 85.7679 - val_loss: 1008.2764 - val_reconstruction_loss: 923.5493
# Epoch 5/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - kl_loss: 90.7944 - loss: 973.3981 - reconstruction_loss: 882.6038 - val_kl_loss: 91.1640 - val_loss: 931.9117 - val_reconstruction_loss: 841.1517
# Epoch 6/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 92.1381 - loss: 921.5719 - reconstruction_loss: 829.4338 - val_kl_loss: 92.3964 - val_loss: 900.4927 - val_reconstruction_loss: 808.5405
# Epoch 7/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 93.5051 - loss: 895.3790 - reconstruction_loss: 801.8738 - val_kl_loss: 93.5676 - val_loss: 845.3641 - val_reconstruction_loss: 751.9523
# Epoch 8/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 92.3362 - loss: 851.9501 - reconstruction_loss: 759.6138 - val_kl_loss: 95.6194 - val_loss: 845.8322 - val_reconstruction_loss: 752.2273
# Epoch 9/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 95.7821 - loss: 850.0323 - reconstruction_loss: 754.2502 - val_kl_loss: 95.9485 - val_loss: 873.8870 - val_reconstruction_loss: 777.4284
# Epoch 10/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 95.2718 - loss: 844.4435 - reconstruction_loss: 749.1718 - val_kl_loss: 88.8505 - val_loss: 812.3358 - val_reconstruction_loss: 724.6833
# Epoch 11/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 92.4498 - loss: 792.8723 - reconstruction_loss: 700.4225 - val_kl_loss: 93.1807 - val_loss: 812.6892 - val_reconstruction_loss: 719.4284
# Epoch 12/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 92.4762 - loss: 774.8931 - reconstruction_loss: 682.4167 - val_kl_loss: 93.5416 - val_loss: 797.4974 - val_reconstruction_loss: 704.1121
# Epoch 13/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 94.7608 - loss: 775.0952 - reconstruction_loss: 680.3345 - val_kl_loss: 94.8401 - val_loss: 752.2362 - val_reconstruction_loss: 656.7853
# Epoch 14/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - kl_loss: 91.5147 - loss: 727.1175 - reconstruction_loss: 635.6028 - val_kl_loss: 89.2605 - val_loss: 775.1700 - val_reconstruction_loss: 684.6899
# Epoch 15/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - kl_loss: 91.3913 - loss: 720.2589 - reconstruction_loss: 628.8675 - val_kl_loss: 96.9586 - val_loss: 735.0892 - val_reconstruction_loss: 637.8777
# Epoch 16/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 95.3090 - loss: 707.7867 - reconstruction_loss: 612.4777 - val_kl_loss: 90.6863 - val_loss: 713.9601 - val_reconstruction_loss: 624.2898
# Epoch 17/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - kl_loss: 91.6562 - loss: 693.1147 - reconstruction_loss: 601.4585 - val_kl_loss: 92.2423 - val_loss: 694.9138 - val_reconstruction_loss: 603.3182
# Epoch 18/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 92.8520 - loss: 668.1705 - reconstruction_loss: 575.3184 - val_kl_loss: 92.4555 - val_loss: 713.0736 - val_reconstruction_loss: 620.5707
# Epoch 19/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - kl_loss: 94.3808 - loss: 656.7929 - reconstruction_loss: 562.4121 - val_kl_loss: 92.5965 - val_loss: 669.8875 - val_reconstruction_loss: 575.0554
# Epoch 20/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 92.1268 - loss: 629.1099 - reconstruction_loss: 536.9832 - val_kl_loss: 92.3310 - val_loss: 645.7644 - val_reconstruction_loss: 553.7556
# Epoch 21/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 93.6019 - loss: 615.9583 - reconstruction_loss: 522.3564 - val_kl_loss: 91.3223 - val_loss: 639.4917 - val_reconstruction_loss: 549.3585
# Epoch 22/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - kl_loss: 91.7070 - loss: 607.3748 - reconstruction_loss: 515.6678 - val_kl_loss: 93.4414 - val_loss: 603.6957 - val_reconstruction_loss: 511.1930
# Epoch 23/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 91.1946 - loss: 582.4584 - reconstruction_loss: 491.2637 - val_kl_loss: 92.8155 - val_loss: 647.0927 - val_reconstruction_loss: 553.5639
# Epoch 24/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - kl_loss: 91.8327 - loss: 572.7245 - reconstruction_loss: 480.8918 - val_kl_loss: 90.4173 - val_loss: 596.9989 - val_reconstruction_loss: 506.1826
# Epoch 25/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 93.3592 - loss: 574.7118 - reconstruction_loss: 481.3525 - val_kl_loss: 89.1005 - val_loss: 599.0384 - val_reconstruction_loss: 508.3910
# Epoch 26/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 90.2582 - loss: 561.2885 - reconstruction_loss: 471.0303 - val_kl_loss: 88.6606 - val_loss: 567.5902 - val_reconstruction_loss: 478.3409
# Epoch 27/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 90.0702 - loss: 538.9881 - reconstruction_loss: 448.9179 - val_kl_loss: 91.1568 - val_loss: 649.2290 - val_reconstruction_loss: 560.3585
# Epoch 28/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 92.2899 - loss: 557.8986 - reconstruction_loss: 465.6085 - val_kl_loss: 89.0039 - val_loss: 592.5793 - val_reconstruction_loss: 504.4307
# Epoch 29/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 91.5831 - loss: 539.5608 - reconstruction_loss: 447.9776 - val_kl_loss: 90.9172 - val_loss: 619.7784 - val_reconstruction_loss: 528.8343
# Epoch 30/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 90.7725 - loss: 544.1981 - reconstruction_loss: 453.4255 - val_kl_loss: 92.0096 - val_loss: 548.1324 - val_reconstruction_loss: 455.2662
# Epoch 31/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 90.4385 - loss: 500.8679 - reconstruction_loss: 410.4294 - val_kl_loss: 92.6929 - val_loss: 558.8481 - val_reconstruction_loss: 465.4894
# Epoch 32/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 92.7457 - loss: 495.4362 - reconstruction_loss: 402.6905 - val_kl_loss: 89.5959 - val_loss: 560.0950 - val_reconstruction_loss: 471.9391
# Epoch 33/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - kl_loss: 89.9237 - loss: 498.8333 - reconstruction_loss: 408.9097 - val_kl_loss: 87.9088 - val_loss: 529.2003 - val_reconstruction_loss: 442.9873
# Epoch 34/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 88.5636 - loss: 486.1443 - reconstruction_loss: 397.5807 - val_kl_loss: 85.9341 - val_loss: 549.7194 - val_reconstruction_loss: 463.4237
# Epoch 35/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 89.7320 - loss: 493.5556 - reconstruction_loss: 403.8236 - val_kl_loss: 92.3591 - val_loss: 556.0643 - val_reconstruction_loss: 464.4420
# Epoch 36/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 90.9407 - loss: 484.7855 - reconstruction_loss: 393.8448 - val_kl_loss: 88.3897 - val_loss: 523.6793 - val_reconstruction_loss: 434.9107
# Epoch 37/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 88.9129 - loss: 469.8918 - reconstruction_loss: 380.9789 - val_kl_loss: 89.1835 - val_loss: 519.0683 - val_reconstruction_loss: 429.4187
# Epoch 38/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 89.2618 - loss: 466.0201 - reconstruction_loss: 376.7583 - val_kl_loss: 89.0792 - val_loss: 521.7239 - val_reconstruction_loss: 431.8589
# Epoch 39/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 88.1732 - loss: 455.8979 - reconstruction_loss: 367.7247 - val_kl_loss: 87.7608 - val_loss: 500.2948 - val_reconstruction_loss: 414.1310
# Epoch 40/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 87.8540 - loss: 444.6285 - reconstruction_loss: 356.7745 - val_kl_loss: 87.3757 - val_loss: 518.9737 - val_reconstruction_loss: 432.6517
# Epoch 41/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 87.7248 - loss: 449.0526 - reconstruction_loss: 361.3279 - val_kl_loss: 86.4194 - val_loss: 503.0188 - val_reconstruction_loss: 417.2634
# Epoch 42/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - kl_loss: 88.0750 - loss: 451.1240 - reconstruction_loss: 363.0490 - val_kl_loss: 87.3886 - val_loss: 495.8706 - val_reconstruction_loss: 408.5015
# Epoch 43/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 87.2239 - loss: 436.4294 - reconstruction_loss: 349.2054 - val_kl_loss: 87.5803 - val_loss: 507.9384 - val_reconstruction_loss: 420.4555
# Epoch 44/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 87.5113 - loss: 430.4169 - reconstruction_loss: 342.9056 - val_kl_loss: 87.4206 - val_loss: 502.9147 - val_reconstruction_loss: 416.6530
# Epoch 45/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 87.1011 - loss: 427.6059 - reconstruction_loss: 340.5049 - val_kl_loss: 85.9801 - val_loss: 500.3065 - val_reconstruction_loss: 414.9028
# Epoch 46/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 88.2337 - loss: 451.2375 - reconstruction_loss: 363.0038 - val_kl_loss: 88.0132 - val_loss: 484.5363 - val_reconstruction_loss: 398.5216
# Epoch 47/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 88.3704 - loss: 429.9725 - reconstruction_loss: 341.6021 - val_kl_loss: 88.1535 - val_loss: 459.2472 - val_reconstruction_loss: 370.9164
# Epoch 48/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 87.0528 - loss: 411.9204 - reconstruction_loss: 324.8676 - val_kl_loss: 85.4033 - val_loss: 466.3878 - val_reconstruction_loss: 380.1815
# Epoch 49/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 86.0186 - loss: 413.6690 - reconstruction_loss: 327.6504 - val_kl_loss: 84.5641 - val_loss: 472.7867 - val_reconstruction_loss: 386.9950
# Epoch 50/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 85.3468 - loss: 408.5998 - reconstruction_loss: 323.2531 - val_kl_loss: 82.6903 - val_loss: 483.9716 - val_reconstruction_loss: 402.9406
# Epoch 51/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 85.1190 - loss: 407.9302 - reconstruction_loss: 322.8112 - val_kl_loss: 83.7937 - val_loss: 471.3031 - val_reconstruction_loss: 386.9544
# Epoch 52/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 86.0662 - loss: 415.4035 - reconstruction_loss: 329.3372 - val_kl_loss: 85.2274 - val_loss: 485.8975 - val_reconstruction_loss: 400.3529
# Epoch 53/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 85.0771 - loss: 414.7422 - reconstruction_loss: 329.6651 - val_kl_loss: 82.0784 - val_loss: 456.2509 - val_reconstruction_loss: 373.7818
# Epoch 54/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 84.9572 - loss: 402.2976 - reconstruction_loss: 317.3404 - val_kl_loss: 86.1595 - val_loss: 464.7581 - val_reconstruction_loss: 379.3153
# Epoch 55/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 85.8765 - loss: 394.5844 - reconstruction_loss: 308.7078 - val_kl_loss: 88.6610 - val_loss: 491.5563 - val_reconstruction_loss: 404.2859
# Epoch 56/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - kl_loss: 87.3640 - loss: 410.8434 - reconstruction_loss: 323.4795 - val_kl_loss: 83.4320 - val_loss: 461.6180 - val_reconstruction_loss: 380.4408
# Epoch 57/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 84.8750 - loss: 392.2930 - reconstruction_loss: 307.4179 - val_kl_loss: 83.4200 - val_loss: 447.5235 - val_reconstruction_loss: 364.4302
# Epoch 58/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 84.8097 - loss: 388.9606 - reconstruction_loss: 304.1509 - val_kl_loss: 84.7476 - val_loss: 454.1879 - val_reconstruction_loss: 368.9849
# Epoch 59/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 85.0245 - loss: 391.3654 - reconstruction_loss: 306.3409 - val_kl_loss: 85.5500 - val_loss: 454.3866 - val_reconstruction_loss: 369.6361
# Epoch 60/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 85.0207 - loss: 387.5921 - reconstruction_loss: 302.5714 - val_kl_loss: 81.1598 - val_loss: 442.6042 - val_reconstruction_loss: 363.3403
# Epoch 61/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 82.5201 - loss: 372.8066 - reconstruction_loss: 290.2865 - val_kl_loss: 83.0015 - val_loss: 467.1700 - val_reconstruction_loss: 385.3116
# Epoch 62/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 84.7904 - loss: 389.9197 - reconstruction_loss: 305.1294 - val_kl_loss: 85.3143 - val_loss: 441.4781 - val_reconstruction_loss: 355.1674
# Epoch 63/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 87.2117 - loss: 400.1401 - reconstruction_loss: 312.9284 - val_kl_loss: 85.6419 - val_loss: 456.8978 - val_reconstruction_loss: 370.2784
# Epoch 64/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 87.3736 - loss: 418.0750 - reconstruction_loss: 330.7013 - val_kl_loss: 82.9678 - val_loss: 457.2211 - val_reconstruction_loss: 373.1440
# Epoch 65/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 85.1547 - loss: 392.0803 - reconstruction_loss: 306.9255 - val_kl_loss: 80.5080 - val_loss: 442.9302 - val_reconstruction_loss: 361.7041
# Epoch 66/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 82.9069 - loss: 374.6705 - reconstruction_loss: 291.7637 - val_kl_loss: 82.0639 - val_loss: 429.3427 - val_reconstruction_loss: 346.2706
# Epoch 67/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 82.8304 - loss: 369.4584 - reconstruction_loss: 286.6280 - val_kl_loss: 83.6634 - val_loss: 423.5314 - val_reconstruction_loss: 340.8646
# Epoch 68/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 84.6984 - loss: 374.7711 - reconstruction_loss: 290.0726 - val_kl_loss: 81.1407 - val_loss: 440.5525 - val_reconstruction_loss: 360.4900
# Epoch 69/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 84.3565 - loss: 376.2672 - reconstruction_loss: 291.9107 - val_kl_loss: 82.1590 - val_loss: 473.7812 - val_reconstruction_loss: 392.2271
# Epoch 70/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 83.8102 - loss: 380.5560 - reconstruction_loss: 296.7458 - val_kl_loss: 79.9234 - val_loss: 443.2292 - val_reconstruction_loss: 364.0692
# Epoch 71/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 81.5965 - loss: 362.6500 - reconstruction_loss: 281.0535 - val_kl_loss: 84.2847 - val_loss: 444.4120 - val_reconstruction_loss: 360.7615
# Epoch 72/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 83.4159 - loss: 363.0633 - reconstruction_loss: 279.6474 - val_kl_loss: 85.2341 - val_loss: 430.6126 - val_reconstruction_loss: 345.4014
# Epoch 73/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 84.5390 - loss: 368.5813 - reconstruction_loss: 284.0423 - val_kl_loss: 82.6693 - val_loss: 434.1837 - val_reconstruction_loss: 351.3121
# Epoch 74/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 84.0322 - loss: 382.6516 - reconstruction_loss: 298.6194 - val_kl_loss: 83.0800 - val_loss: 457.1117 - val_reconstruction_loss: 373.8665
# Epoch 75/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 83.1782 - loss: 372.2152 - reconstruction_loss: 289.0370 - val_kl_loss: 80.0778 - val_loss: 440.7182 - val_reconstruction_loss: 359.8423
# Epoch 76/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 83.2201 - loss: 365.6158 - reconstruction_loss: 282.3958 - val_kl_loss: 82.0709 - val_loss: 418.0212 - val_reconstruction_loss: 337.9243
# Epoch 77/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 82.5837 - loss: 355.2231 - reconstruction_loss: 272.6393 - val_kl_loss: 80.6418 - val_loss: 421.5230 - val_reconstruction_loss: 341.4232
# Epoch 78/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 82.8312 - loss: 352.1073 - reconstruction_loss: 269.2761 - val_kl_loss: 85.1790 - val_loss: 430.9429 - val_reconstruction_loss: 347.8894
# Epoch 79/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 84.1363 - loss: 359.2264 - reconstruction_loss: 275.0901 - val_kl_loss: 83.3573 - val_loss: 423.8741 - val_reconstruction_loss: 341.0422
# Epoch 80/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 83.6045 - loss: 354.7088 - reconstruction_loss: 271.1043 - val_kl_loss: 83.4097 - val_loss: 451.0486 - val_reconstruction_loss: 368.0926
# Epoch 81/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 83.2227 - loss: 362.8669 - reconstruction_loss: 279.6442 - val_kl_loss: 82.3180 - val_loss: 437.6297 - val_reconstruction_loss: 355.7127
# Epoch 82/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 85.2352 - loss: 365.0457 - reconstruction_loss: 279.8105 - val_kl_loss: 82.6172 - val_loss: 414.2447 - val_reconstruction_loss: 332.3302
# Epoch 83/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 83.0448 - loss: 351.7456 - reconstruction_loss: 268.7008 - val_kl_loss: 80.0917 - val_loss: 415.9842 - val_reconstruction_loss: 336.2113
# Epoch 84/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 81.7198 - loss: 347.8080 - reconstruction_loss: 266.0881 - val_kl_loss: 82.1339 - val_loss: 411.5059 - val_reconstruction_loss: 329.6235
# Epoch 85/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 83.9492 - loss: 351.1360 - reconstruction_loss: 267.1869 - val_kl_loss: 81.6131 - val_loss: 411.5997 - val_reconstruction_loss: 330.8467
# Epoch 86/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 81.6507 - loss: 345.1778 - reconstruction_loss: 263.5272 - val_kl_loss: 82.2675 - val_loss: 438.7896 - val_reconstruction_loss: 356.6907
# Epoch 87/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 82.3137 - loss: 353.3459 - reconstruction_loss: 271.0323 - val_kl_loss: 80.1779 - val_loss: 409.3058 - val_reconstruction_loss: 328.4670
# Epoch 88/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 81.5308 - loss: 349.0600 - reconstruction_loss: 267.5291 - val_kl_loss: 86.9492 - val_loss: 418.6692 - val_reconstruction_loss: 332.9285
# Epoch 89/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 84.0166 - loss: 353.4786 - reconstruction_loss: 269.4620 - val_kl_loss: 80.1842 - val_loss: 415.9236 - val_reconstruction_loss: 336.1909
# Epoch 90/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 82.1900 - loss: 354.8726 - reconstruction_loss: 272.6826 - val_kl_loss: 81.0460 - val_loss: 396.9041 - val_reconstruction_loss: 316.7004
# Epoch 91/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 82.2541 - loss: 340.8519 - reconstruction_loss: 258.5978 - val_kl_loss: 79.3969 - val_loss: 404.7474 - val_reconstruction_loss: 326.1257
# Epoch 92/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 80.1379 - loss: 333.9805 - reconstruction_loss: 253.8425 - val_kl_loss: 83.2680 - val_loss: 399.8225 - val_reconstruction_loss: 316.9895
# Epoch 93/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 83.8232 - loss: 342.5558 - reconstruction_loss: 258.7325 - val_kl_loss: 81.0548 - val_loss: 399.4174 - val_reconstruction_loss: 318.8183
# Epoch 94/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 80.5467 - loss: 330.0091 - reconstruction_loss: 249.4624 - val_kl_loss: 81.6409 - val_loss: 409.9789 - val_reconstruction_loss: 329.5085
# Epoch 95/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 83.0652 - loss: 341.0729 - reconstruction_loss: 258.0077 - val_kl_loss: 81.6716 - val_loss: 427.4537 - val_reconstruction_loss: 346.1619
# Epoch 96/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 83.5418 - loss: 351.5388 - reconstruction_loss: 267.9970 - val_kl_loss: 83.7281 - val_loss: 421.6479 - val_reconstruction_loss: 337.2936
# Epoch 97/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 82.8401 - loss: 337.7033 - reconstruction_loss: 254.8632 - val_kl_loss: 80.8314 - val_loss: 395.9446 - val_reconstruction_loss: 315.2391
# Epoch 98/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 80.0048 - loss: 330.0667 - reconstruction_loss: 250.0620 - val_kl_loss: 83.2845 - val_loss: 400.4761 - val_reconstruction_loss: 316.8853
# Epoch 99/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 81.9774 - loss: 331.4212 - reconstruction_loss: 249.4438 - val_kl_loss: 79.6595 - val_loss: 400.2693 - val_reconstruction_loss: 319.5538
# Epoch 100/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 82.5091 - loss: 334.7808 - reconstruction_loss: 252.2717 - val_kl_loss: 80.1236 - val_loss: 405.0621 - val_reconstruction_loss: 325.3214
# Epoch 101/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 80.6354 - loss: 333.5079 - reconstruction_loss: 252.8725 - val_kl_loss: 79.6227 - val_loss: 400.5209 - val_reconstruction_loss: 321.3104
# Epoch 102/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 81.3479 - loss: 336.9026 - reconstruction_loss: 255.5547 - val_kl_loss: 81.5925 - val_loss: 394.0158 - val_reconstruction_loss: 313.3678
# Epoch 103/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 81.3477 - loss: 325.4414 - reconstruction_loss: 244.0937 - val_kl_loss: 83.5624 - val_loss: 390.5419 - val_reconstruction_loss: 307.5874
# Epoch 104/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 83.1094 - loss: 339.1559 - reconstruction_loss: 256.0466 - val_kl_loss: 80.8842 - val_loss: 403.5270 - val_reconstruction_loss: 323.5783
# Epoch 105/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 81.2575 - loss: 332.8925 - reconstruction_loss: 251.6351 - val_kl_loss: 80.8754 - val_loss: 383.8248 - val_reconstruction_loss: 302.1918
# Epoch 106/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 82.5549 - loss: 335.5651 - reconstruction_loss: 253.0102 - val_kl_loss: 78.1891 - val_loss: 383.8035 - val_reconstruction_loss: 304.8259
# Epoch 107/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - kl_loss: 80.8298 - loss: 320.9863 - reconstruction_loss: 240.1565 - val_kl_loss: 85.5418 - val_loss: 400.8424 - val_reconstruction_loss: 315.4078
# Epoch 108/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 82.8309 - loss: 336.9123 - reconstruction_loss: 254.0814 - val_kl_loss: 79.5706 - val_loss: 383.8745 - val_reconstruction_loss: 303.0648
# Epoch 109/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 82.1118 - loss: 335.1332 - reconstruction_loss: 253.0215 - val_kl_loss: 80.5464 - val_loss: 408.2639 - val_reconstruction_loss: 326.8441
# Epoch 110/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 81.9384 - loss: 331.3935 - reconstruction_loss: 249.4551 - val_kl_loss: 79.8769 - val_loss: 389.7136 - val_reconstruction_loss: 309.9092
# Epoch 111/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 80.6280 - loss: 319.4044 - reconstruction_loss: 238.7765 - val_kl_loss: 79.3096 - val_loss: 398.3695 - val_reconstruction_loss: 320.2573
# Epoch 112/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 79.8187 - loss: 314.3241 - reconstruction_loss: 234.5054 - val_kl_loss: 82.8415 - val_loss: 390.7304 - val_reconstruction_loss: 308.6094
# Epoch 113/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 81.6532 - loss: 315.6775 - reconstruction_loss: 234.0242 - val_kl_loss: 81.6974 - val_loss: 386.6718 - val_reconstruction_loss: 305.0277
# Epoch 114/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - kl_loss: 82.4303 - loss: 329.4008 - reconstruction_loss: 246.9706 - val_kl_loss: 79.6242 - val_loss: 399.6771 - val_reconstruction_loss: 320.2741
# Epoch 115/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 80.6837 - loss: 325.4023 - reconstruction_loss: 244.7185 - val_kl_loss: 81.5736 - val_loss: 407.0112 - val_reconstruction_loss: 326.1486
# Epoch 116/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 82.5451 - loss: 330.4673 - reconstruction_loss: 247.9222 - val_kl_loss: 81.6457 - val_loss: 394.4061 - val_reconstruction_loss: 313.8721
# Epoch 117/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 81.9878 - loss: 319.0020 - reconstruction_loss: 237.0141 - val_kl_loss: 79.8912 - val_loss: 402.0752 - val_reconstruction_loss: 321.7466
# Epoch 118/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 81.9932 - loss: 322.8109 - reconstruction_loss: 240.8177 - val_kl_loss: 79.7073 - val_loss: 391.7199 - val_reconstruction_loss: 312.0805
# Epoch 119/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 80.2836 - loss: 320.2055 - reconstruction_loss: 239.9219 - val_kl_loss: 81.0613 - val_loss: 406.4131 - val_reconstruction_loss: 324.4371
# Epoch 120/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 81.7309 - loss: 323.0464 - reconstruction_loss: 241.3155 - val_kl_loss: 81.4995 - val_loss: 398.3072 - val_reconstruction_loss: 316.5871
# Epoch 121/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 81.4414 - loss: 329.1332 - reconstruction_loss: 247.6918 - val_kl_loss: 83.6238 - val_loss: 393.8441 - val_reconstruction_loss: 309.4197
# Epoch 122/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 81.3883 - loss: 322.8833 - reconstruction_loss: 241.4949 - val_kl_loss: 81.8093 - val_loss: 380.5014 - val_reconstruction_loss: 298.8026
# Epoch 123/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 81.2973 - loss: 307.3000 - reconstruction_loss: 226.0027 - val_kl_loss: 82.8993 - val_loss: 464.2408 - val_reconstruction_loss: 380.6511
# Epoch 124/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 82.1513 - loss: 348.6654 - reconstruction_loss: 266.5142 - val_kl_loss: 80.6053 - val_loss: 396.0922 - val_reconstruction_loss: 315.0860
# Epoch 125/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 79.9255 - loss: 325.6722 - reconstruction_loss: 245.7467 - val_kl_loss: 81.9154 - val_loss: 391.0801 - val_reconstruction_loss: 308.4094
# Epoch 126/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 79.9565 - loss: 312.8456 - reconstruction_loss: 232.8891 - val_kl_loss: 77.7631 - val_loss: 377.3076 - val_reconstruction_loss: 299.4232
# Epoch 127/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 80.4766 - loss: 310.5760 - reconstruction_loss: 230.0995 - val_kl_loss: 81.2838 - val_loss: 374.6067 - val_reconstruction_loss: 294.0773
# Epoch 128/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 81.7380 - loss: 312.8325 - reconstruction_loss: 231.0945 - val_kl_loss: 80.0099 - val_loss: 380.8443 - val_reconstruction_loss: 300.0672
# Epoch 129/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 79.9500 - loss: 309.9766 - reconstruction_loss: 230.0266 - val_kl_loss: 82.9812 - val_loss: 382.7874 - val_reconstruction_loss: 301.3391
# Epoch 130/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 81.5359 - loss: 316.4133 - reconstruction_loss: 234.8773 - val_kl_loss: 84.7325 - val_loss: 408.4728 - val_reconstruction_loss: 325.2368
# Epoch 131/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 81.6780 - loss: 318.2773 - reconstruction_loss: 236.5993 - val_kl_loss: 79.5641 - val_loss: 374.5429 - val_reconstruction_loss: 296.2978
# Epoch 132/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 80.6950 - loss: 306.9406 - reconstruction_loss: 226.2456 - val_kl_loss: 81.4035 - val_loss: 378.9255 - val_reconstruction_loss: 298.4231
# Epoch 133/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 80.9048 - loss: 311.7514 - reconstruction_loss: 230.8466 - val_kl_loss: 81.4754 - val_loss: 385.1564 - val_reconstruction_loss: 302.3102
# Epoch 134/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 80.9578 - loss: 309.3553 - reconstruction_loss: 228.3975 - val_kl_loss: 78.5675 - val_loss: 381.2329 - val_reconstruction_loss: 302.9076
# Epoch 135/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 79.9439 - loss: 316.7629 - reconstruction_loss: 236.8189 - val_kl_loss: 79.1576 - val_loss: 389.7003 - val_reconstruction_loss: 310.9521
# Epoch 136/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 79.8389 - loss: 307.1569 - reconstruction_loss: 227.3180 - val_kl_loss: 79.1465 - val_loss: 398.2762 - val_reconstruction_loss: 317.8377
# Epoch 137/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 79.1577 - loss: 305.0072 - reconstruction_loss: 225.8495 - val_kl_loss: 81.3728 - val_loss: 380.4092 - val_reconstruction_loss: 299.8575
# Epoch 138/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 79.9882 - loss: 305.1177 - reconstruction_loss: 225.1295 - val_kl_loss: 78.8040 - val_loss: 369.4133 - val_reconstruction_loss: 290.2644
# Epoch 139/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 78.4850 - loss: 298.7355 - reconstruction_loss: 220.2506 - val_kl_loss: 81.8064 - val_loss: 375.9957 - val_reconstruction_loss: 294.0780
# Epoch 140/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 81.7389 - loss: 311.3423 - reconstruction_loss: 229.6035 - val_kl_loss: 81.5485 - val_loss: 391.3671 - val_reconstruction_loss: 310.0122
# Epoch 141/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 80.7239 - loss: 312.9901 - reconstruction_loss: 232.2662 - val_kl_loss: 80.0976 - val_loss: 377.3141 - val_reconstruction_loss: 297.4630
# Epoch 142/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 80.9360 - loss: 311.2234 - reconstruction_loss: 230.2874 - val_kl_loss: 81.2118 - val_loss: 389.4958 - val_reconstruction_loss: 309.1017
# Epoch 143/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 80.4132 - loss: 311.1863 - reconstruction_loss: 230.7731 - val_kl_loss: 81.3678 - val_loss: 382.0347 - val_reconstruction_loss: 303.1508
# Epoch 144/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 81.1857 - loss: 306.5770 - reconstruction_loss: 225.3913 - val_kl_loss: 78.2403 - val_loss: 369.5266 - val_reconstruction_loss: 290.3615
# Epoch 145/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 80.2847 - loss: 306.5042 - reconstruction_loss: 226.2196 - val_kl_loss: 84.2369 - val_loss: 412.4408 - val_reconstruction_loss: 328.1440
# Epoch 146/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 82.2563 - loss: 319.4056 - reconstruction_loss: 237.1493 - val_kl_loss: 81.9430 - val_loss: 379.1017 - val_reconstruction_loss: 296.6603
# Epoch 147/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 80.4641 - loss: 310.9165 - reconstruction_loss: 230.4524 - val_kl_loss: 81.4182 - val_loss: 367.8783 - val_reconstruction_loss: 287.2203
# Epoch 148/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 81.5407 - loss: 311.7899 - reconstruction_loss: 230.2492 - val_kl_loss: 77.8792 - val_loss: 384.9253 - val_reconstruction_loss: 307.9244
# Epoch 149/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 79.4245 - loss: 296.8745 - reconstruction_loss: 217.4501 - val_kl_loss: 81.0606 - val_loss: 368.5749 - val_reconstruction_loss: 287.8575
# Epoch 150/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - kl_loss: 82.6411 - loss: 312.4556 - reconstruction_loss: 229.8144 - val_kl_loss: 80.4685 - val_loss: 381.6153 - val_reconstruction_loss: 303.3277
# Epoch 151/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 82.7176 - loss: 312.2405 - reconstruction_loss: 229.5229 - val_kl_loss: 80.4930 - val_loss: 372.9447 - val_reconstruction_loss: 291.6775
# Epoch 152/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 80.3849 - loss: 304.7430 - reconstruction_loss: 224.3581 - val_kl_loss: 79.3621 - val_loss: 373.7169 - val_reconstruction_loss: 295.8274
# Epoch 153/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 80.2527 - loss: 300.7652 - reconstruction_loss: 220.5125 - val_kl_loss: 80.7022 - val_loss: 367.3850 - val_reconstruction_loss: 286.5623
# Epoch 154/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 80.4853 - loss: 294.5930 - reconstruction_loss: 214.1077 - val_kl_loss: 78.7713 - val_loss: 366.7374 - val_reconstruction_loss: 288.1682
# Epoch 155/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 79.0959 - loss: 296.1738 - reconstruction_loss: 217.0780 - val_kl_loss: 80.0504 - val_loss: 375.1211 - val_reconstruction_loss: 294.4794
# Epoch 156/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 79.3692 - loss: 302.3571 - reconstruction_loss: 222.9879 - val_kl_loss: 85.5849 - val_loss: 374.5037 - val_reconstruction_loss: 289.0808
# Epoch 157/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 82.3669 - loss: 302.1248 - reconstruction_loss: 219.7579 - val_kl_loss: 78.2758 - val_loss: 381.3776 - val_reconstruction_loss: 303.7358
# Epoch 158/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 79.7612 - loss: 297.1260 - reconstruction_loss: 217.3649 - val_kl_loss: 79.8510 - val_loss: 376.8154 - val_reconstruction_loss: 297.3760
# Epoch 159/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 81.0291 - loss: 299.2765 - reconstruction_loss: 218.2474 - val_kl_loss: 79.6473 - val_loss: 367.6180 - val_reconstruction_loss: 287.3070
# Epoch 160/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 80.7189 - loss: 296.1150 - reconstruction_loss: 215.3961 - val_kl_loss: 79.6133 - val_loss: 366.8378 - val_reconstruction_loss: 286.6399
# Epoch 161/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 79.5649 - loss: 298.1360 - reconstruction_loss: 218.5710 - val_kl_loss: 80.9525 - val_loss: 397.5909 - val_reconstruction_loss: 319.4158
# Epoch 162/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 81.5085 - loss: 307.6372 - reconstruction_loss: 226.1287 - val_kl_loss: 82.3684 - val_loss: 378.2477 - val_reconstruction_loss: 297.2429
# Epoch 163/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 80.2812 - loss: 295.2633 - reconstruction_loss: 214.9821 - val_kl_loss: 80.6721 - val_loss: 369.7744 - val_reconstruction_loss: 290.2484
# Epoch 164/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 78.8397 - loss: 293.0698 - reconstruction_loss: 214.2301 - val_kl_loss: 82.7816 - val_loss: 371.0274 - val_reconstruction_loss: 288.2652
# Epoch 165/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 80.5297 - loss: 298.8645 - reconstruction_loss: 218.3348 - val_kl_loss: 81.6523 - val_loss: 382.1020 - val_reconstruction_loss: 300.5323
# Epoch 166/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 81.1129 - loss: 303.1102 - reconstruction_loss: 221.9973 - val_kl_loss: 82.4888 - val_loss: 365.4862 - val_reconstruction_loss: 282.9159
# Epoch 167/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 81.1604 - loss: 296.4023 - reconstruction_loss: 215.2419 - val_kl_loss: 80.7692 - val_loss: 392.0692 - val_reconstruction_loss: 311.5490
# Epoch 168/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - kl_loss: 80.7463 - loss: 309.6566 - reconstruction_loss: 228.9103 - val_kl_loss: 77.7225 - val_loss: 366.0973 - val_reconstruction_loss: 288.7922
# Epoch 169/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 78.6149 - loss: 287.9650 - reconstruction_loss: 209.3501 - val_kl_loss: 80.1722 - val_loss: 356.6843 - val_reconstruction_loss: 276.5501
# Epoch 170/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 80.1511 - loss: 294.1895 - reconstruction_loss: 214.0384 - val_kl_loss: 77.2886 - val_loss: 367.0623 - val_reconstruction_loss: 289.1545
# Epoch 171/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 79.4330 - loss: 299.2997 - reconstruction_loss: 219.8666 - val_kl_loss: 80.5101 - val_loss: 375.5540 - val_reconstruction_loss: 295.4082
# Epoch 172/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 80.5663 - loss: 302.0683 - reconstruction_loss: 221.5019 - val_kl_loss: 80.0289 - val_loss: 375.9964 - val_reconstruction_loss: 299.7289
# Epoch 173/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 80.1608 - loss: 293.6928 - reconstruction_loss: 213.5321 - val_kl_loss: 79.3806 - val_loss: 359.3882 - val_reconstruction_loss: 280.1447
# Epoch 174/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 79.2853 - loss: 292.4906 - reconstruction_loss: 213.2053 - val_kl_loss: 79.1707 - val_loss: 355.2225 - val_reconstruction_loss: 275.4264
# Epoch 175/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 80.0285 - loss: 291.8506 - reconstruction_loss: 211.8221 - val_kl_loss: 79.9355 - val_loss: 372.1384 - val_reconstruction_loss: 291.6205
# Epoch 176/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 80.5898 - loss: 303.6421 - reconstruction_loss: 223.0523 - val_kl_loss: 80.0643 - val_loss: 379.5208 - val_reconstruction_loss: 301.2973
# Epoch 177/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 79.0851 - loss: 298.9272 - reconstruction_loss: 219.8422 - val_kl_loss: 78.8407 - val_loss: 371.3419 - val_reconstruction_loss: 292.5257
# Epoch 178/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 79.4006 - loss: 295.1102 - reconstruction_loss: 215.7096 - val_kl_loss: 82.5879 - val_loss: 364.4046 - val_reconstruction_loss: 281.2528
# Epoch 179/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 80.0866 - loss: 297.4530 - reconstruction_loss: 217.3665 - val_kl_loss: 81.1979 - val_loss: 365.3859 - val_reconstruction_loss: 284.8004
# Epoch 180/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 81.4068 - loss: 294.3511 - reconstruction_loss: 212.9444 - val_kl_loss: 78.4684 - val_loss: 366.5174 - val_reconstruction_loss: 288.1338
# Epoch 181/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 78.6410 - loss: 289.7500 - reconstruction_loss: 211.1090 - val_kl_loss: 75.4088 - val_loss: 356.9524 - val_reconstruction_loss: 282.4943
# Epoch 182/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 78.3008 - loss: 287.3172 - reconstruction_loss: 209.0164 - val_kl_loss: 83.4787 - val_loss: 364.4212 - val_reconstruction_loss: 280.5425
# Epoch 183/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 80.5753 - loss: 295.2972 - reconstruction_loss: 214.7219 - val_kl_loss: 80.1166 - val_loss: 371.8171 - val_reconstruction_loss: 293.3160
# Epoch 184/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 80.1091 - loss: 293.5210 - reconstruction_loss: 213.4119 - val_kl_loss: 80.4463 - val_loss: 356.8107 - val_reconstruction_loss: 276.3350
# Epoch 185/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 79.3580 - loss: 288.3471 - reconstruction_loss: 208.9891 - val_kl_loss: 82.3347 - val_loss: 361.0343 - val_reconstruction_loss: 280.0491
# Epoch 186/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 80.7809 - loss: 284.1487 - reconstruction_loss: 203.3678 - val_kl_loss: 80.5308 - val_loss: 369.8561 - val_reconstruction_loss: 289.8403
# Epoch 187/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 79.9212 - loss: 288.6732 - reconstruction_loss: 208.7520 - val_kl_loss: 81.0027 - val_loss: 358.5842 - val_reconstruction_loss: 277.7286
# Epoch 188/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 79.6368 - loss: 286.5741 - reconstruction_loss: 206.9373 - val_kl_loss: 78.6547 - val_loss: 361.1149 - val_reconstruction_loss: 282.6823
# Epoch 189/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 80.1627 - loss: 293.0318 - reconstruction_loss: 212.8691 - val_kl_loss: 78.4501 - val_loss: 364.9930 - val_reconstruction_loss: 286.5758
# Epoch 190/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 78.3151 - loss: 289.7462 - reconstruction_loss: 211.4312 - val_kl_loss: 77.6510 - val_loss: 373.9696 - val_reconstruction_loss: 295.8802
# Epoch 191/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 80.0740 - loss: 298.2887 - reconstruction_loss: 218.2147 - val_kl_loss: 78.8207 - val_loss: 350.7229 - val_reconstruction_loss: 273.4155
# Epoch 192/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 79.8303 - loss: 289.4456 - reconstruction_loss: 209.6153 - val_kl_loss: 78.6655 - val_loss: 355.2866 - val_reconstruction_loss: 276.5558
# Epoch 193/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 79.7140 - loss: 293.0455 - reconstruction_loss: 213.3315 - val_kl_loss: 81.5327 - val_loss: 364.8939 - val_reconstruction_loss: 283.3366
# Epoch 194/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 79.4450 - loss: 284.1914 - reconstruction_loss: 204.7464 - val_kl_loss: 79.7956 - val_loss: 354.5284 - val_reconstruction_loss: 275.2248
# Epoch 195/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 81.2036 - loss: 289.6035 - reconstruction_loss: 208.3999 - val_kl_loss: 78.5069 - val_loss: 365.5798 - val_reconstruction_loss: 287.0807
# Epoch 196/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 79.2156 - loss: 285.9600 - reconstruction_loss: 206.7443 - val_kl_loss: 83.1658 - val_loss: 347.5197 - val_reconstruction_loss: 263.7222
# Epoch 197/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 79.9240 - loss: 281.2728 - reconstruction_loss: 201.3488 - val_kl_loss: 76.0627 - val_loss: 366.8304 - val_reconstruction_loss: 290.5215
# Epoch 198/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 78.0114 - loss: 284.5686 - reconstruction_loss: 206.5571 - val_kl_loss: 78.8237 - val_loss: 374.6490 - val_reconstruction_loss: 295.6810
# Epoch 199/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 78.0413 - loss: 281.8893 - reconstruction_loss: 203.8480 - val_kl_loss: 80.8948 - val_loss: 361.3035 - val_reconstruction_loss: 280.9308
# Epoch 200/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 79.6947 - loss: 285.6482 - reconstruction_loss: 205.9535 - val_kl_loss: 80.9607 - val_loss: 363.6111 - val_reconstruction_loss: 282.5471
# Epoch 201/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 81.2892 - loss: 293.8392 - reconstruction_loss: 212.5500 - val_kl_loss: 79.6708 - val_loss: 352.9473 - val_reconstruction_loss: 273.5804
# Epoch 202/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 78.7173 - loss: 284.3411 - reconstruction_loss: 205.6238 - val_kl_loss: 78.9911 - val_loss: 350.0391 - val_reconstruction_loss: 270.1277
# Epoch 203/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 77.9904 - loss: 280.3418 - reconstruction_loss: 202.3514 - val_kl_loss: 80.3294 - val_loss: 352.4677 - val_reconstruction_loss: 271.0177
# Epoch 204/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 79.0940 - loss: 284.6731 - reconstruction_loss: 205.5790 - val_kl_loss: 76.1372 - val_loss: 363.9716 - val_reconstruction_loss: 288.2604
# Epoch 205/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 78.6293 - loss: 284.4049 - reconstruction_loss: 205.7756 - val_kl_loss: 81.4082 - val_loss: 353.1471 - val_reconstruction_loss: 271.5645
# Epoch 206/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 79.6018 - loss: 285.6453 - reconstruction_loss: 206.0436 - val_kl_loss: 78.8024 - val_loss: 361.1824 - val_reconstruction_loss: 281.4961
# Epoch 207/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 79.8377 - loss: 286.9211 - reconstruction_loss: 207.0833 - val_kl_loss: 77.9790 - val_loss: 360.6636 - val_reconstruction_loss: 281.6081
# Epoch 208/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 80.2707 - loss: 285.0045 - reconstruction_loss: 204.7338 - val_kl_loss: 81.5179 - val_loss: 364.4060 - val_reconstruction_loss: 282.4870
# Epoch 209/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 82.0557 - loss: 296.3733 - reconstruction_loss: 214.3176 - val_kl_loss: 78.6111 - val_loss: 363.7320 - val_reconstruction_loss: 285.3393
# Epoch 210/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 79.7472 - loss: 285.4307 - reconstruction_loss: 205.6836 - val_kl_loss: 74.8482 - val_loss: 353.9032 - val_reconstruction_loss: 278.5609
# Epoch 211/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 76.8083 - loss: 277.2151 - reconstruction_loss: 200.4068 - val_kl_loss: 76.6791 - val_loss: 370.4638 - val_reconstruction_loss: 295.3838
# Epoch 212/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 78.7356 - loss: 281.8164 - reconstruction_loss: 203.0808 - val_kl_loss: 79.4460 - val_loss: 349.3293 - val_reconstruction_loss: 270.0210
# Epoch 213/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 79.2901 - loss: 278.9095 - reconstruction_loss: 199.6194 - val_kl_loss: 78.8904 - val_loss: 353.6816 - val_reconstruction_loss: 274.5863
# Epoch 214/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 79.3147 - loss: 282.3704 - reconstruction_loss: 203.0556 - val_kl_loss: 78.1077 - val_loss: 364.3672 - val_reconstruction_loss: 285.6743
# Epoch 215/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 79.7217 - loss: 291.6494 - reconstruction_loss: 211.9277 - val_kl_loss: 79.5005 - val_loss: 356.0232 - val_reconstruction_loss: 279.1379
# Epoch 216/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 79.1698 - loss: 281.5399 - reconstruction_loss: 202.3701 - val_kl_loss: 83.7062 - val_loss: 349.9717 - val_reconstruction_loss: 265.5127
# Epoch 217/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 80.0181 - loss: 282.1198 - reconstruction_loss: 202.1017 - val_kl_loss: 80.6117 - val_loss: 354.6269 - val_reconstruction_loss: 273.4396
# Epoch 218/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 80.2098 - loss: 289.3207 - reconstruction_loss: 209.1109 - val_kl_loss: 78.9071 - val_loss: 355.7859 - val_reconstruction_loss: 277.2454
# Epoch 219/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 79.7195 - loss: 283.8759 - reconstruction_loss: 204.1563 - val_kl_loss: 79.5714 - val_loss: 352.4562 - val_reconstruction_loss: 273.7605
# Epoch 220/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 79.5539 - loss: 288.5991 - reconstruction_loss: 209.0452 - val_kl_loss: 77.8074 - val_loss: 357.9129 - val_reconstruction_loss: 280.7253
# Epoch 221/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 78.9010 - loss: 281.6358 - reconstruction_loss: 202.7348 - val_kl_loss: 78.3649 - val_loss: 350.5358 - val_reconstruction_loss: 272.7799
# Epoch 222/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 78.2317 - loss: 274.9429 - reconstruction_loss: 196.7112 - val_kl_loss: 79.1423 - val_loss: 345.7033 - val_reconstruction_loss: 267.5218
# Epoch 223/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 80.1022 - loss: 281.5071 - reconstruction_loss: 201.4049 - val_kl_loss: 79.5684 - val_loss: 351.8645 - val_reconstruction_loss: 272.1855
# Epoch 224/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 79.4046 - loss: 281.6848 - reconstruction_loss: 202.2803 - val_kl_loss: 84.8813 - val_loss: 354.0834 - val_reconstruction_loss: 269.9448
# Epoch 225/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 80.2730 - loss: 282.3613 - reconstruction_loss: 202.0883 - val_kl_loss: 80.8499 - val_loss: 352.9378 - val_reconstruction_loss: 272.5116
# Epoch 226/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 79.6851 - loss: 283.8216 - reconstruction_loss: 204.1365 - val_kl_loss: 79.2999 - val_loss: 349.4415 - val_reconstruction_loss: 269.8033
# Epoch 227/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 80.3962 - loss: 285.8422 - reconstruction_loss: 205.4461 - val_kl_loss: 75.1463 - val_loss: 350.5268 - val_reconstruction_loss: 275.7133
# Epoch 228/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 79.0509 - loss: 276.5190 - reconstruction_loss: 197.4680 - val_kl_loss: 81.3039 - val_loss: 358.9627 - val_reconstruction_loss: 278.7979
# Epoch 229/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 79.5946 - loss: 278.5043 - reconstruction_loss: 198.9097 - val_kl_loss: 80.1070 - val_loss: 384.3366 - val_reconstruction_loss: 306.7634
# Epoch 230/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 80.3822 - loss: 282.6758 - reconstruction_loss: 202.2937 - val_kl_loss: 77.8916 - val_loss: 355.4657 - val_reconstruction_loss: 278.2654
# Epoch 231/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 77.8607 - loss: 274.5103 - reconstruction_loss: 196.6496 - val_kl_loss: 77.4745 - val_loss: 348.5581 - val_reconstruction_loss: 272.7329
# Epoch 232/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 79.6768 - loss: 278.1015 - reconstruction_loss: 198.4247 - val_kl_loss: 78.2925 - val_loss: 346.9070 - val_reconstruction_loss: 270.5940
# Epoch 233/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 78.3482 - loss: 271.3889 - reconstruction_loss: 193.0407 - val_kl_loss: 82.0348 - val_loss: 366.3174 - val_reconstruction_loss: 284.1750
# Epoch 234/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 80.6257 - loss: 282.3705 - reconstruction_loss: 201.7447 - val_kl_loss: 76.2459 - val_loss: 360.8549 - val_reconstruction_loss: 285.7187
# Epoch 235/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 78.2542 - loss: 278.6699 - reconstruction_loss: 200.4156 - val_kl_loss: 77.7477 - val_loss: 356.6365 - val_reconstruction_loss: 279.0474
# Epoch 236/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 77.2288 - loss: 274.2233 - reconstruction_loss: 196.9944 - val_kl_loss: 80.2173 - val_loss: 368.0865 - val_reconstruction_loss: 287.1149
# Epoch 237/1000
# ...
# Epoch 397/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 79.1086 - loss: 265.8382 - reconstruction_loss: 186.7295 - val_kl_loss: 80.4559 - val_loss: 348.1316 - val_reconstruction_loss: 268.3389
# Epoch 398/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 78.3201 - loss: 261.1481 - reconstruction_loss: 182.8279 - val_kl_loss: 78.5731 - val_loss: 339.3890 - val_reconstruction_loss: 262.1930
# Epoch 399/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 77.3118 - loss: 259.2794 - reconstruction_loss: 181.9676 - val_kl_loss: 78.4246 - val_loss: 327.9540 - val_reconstruction_loss: 250.2374
# Epoch 400/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 77.2556 - loss: 256.4067 - reconstruction_loss: 179.1511 - val_kl_loss: 80.2099 - val_loss: 345.6105 - val_reconstruction_loss: 265.2177
# Epoch 401/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 78.0234 - loss: 257.4989 - reconstruction_loss: 179.4755 - val_kl_loss: 79.5927 - val_loss: 339.4997 - val_reconstruction_loss: 261.2502
# Epoch 402/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 78.8454 - loss: 263.5857 - reconstruction_loss: 184.7403 - val_kl_loss: 74.7078 - val_loss: 337.6592 - val_reconstruction_loss: 262.7216
# Epoch 403/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 74.3651 - loss: 252.2226 - reconstruction_loss: 177.8576 - val_kl_loss: 77.7680 - val_loss: 335.6652 - val_reconstruction_loss: 257.9956
# Epoch 404/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 77.8260 - loss: 258.2866 - reconstruction_loss: 180.4605 - val_kl_loss: 77.4469 - val_loss: 329.2484 - val_reconstruction_loss: 252.1134
# Epoch 405/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 77.1120 - loss: 257.3786 - reconstruction_loss: 180.2667 - val_kl_loss: 78.5204 - val_loss: 338.9156 - val_reconstruction_loss: 260.9279
# Epoch 406/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 77.6726 - loss: 260.5789 - reconstruction_loss: 182.9063 - val_kl_loss: 75.6633 - val_loss: 332.9865 - val_reconstruction_loss: 258.4085
# Epoch 407/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 76.3797 - loss: 254.7818 - reconstruction_loss: 178.4021 - val_kl_loss: 76.2610 - val_loss: 327.2832 - val_reconstruction_loss: 251.9379
# Epoch 408/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 76.8413 - loss: 254.4267 - reconstruction_loss: 177.5854 - val_kl_loss: 75.9354 - val_loss: 344.0377 - val_reconstruction_loss: 268.9262
# Epoch 409/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 76.4613 - loss: 258.7650 - reconstruction_loss: 182.3037 - val_kl_loss: 75.9875 - val_loss: 334.6366 - val_reconstruction_loss: 258.4825
# Epoch 410/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 77.1100 - loss: 255.1942 - reconstruction_loss: 178.0842 - val_kl_loss: 77.3219 - val_loss: 328.9953 - val_reconstruction_loss: 250.6717
# Epoch 411/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 77.5824 - loss: 257.7826 - reconstruction_loss: 180.2001 - val_kl_loss: 79.2080 - val_loss: 327.3780 - val_reconstruction_loss: 248.8350
# Epoch 412/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 75.8478 - loss: 254.0592 - reconstruction_loss: 178.2114 - val_kl_loss: 75.3397 - val_loss: 337.5014 - val_reconstruction_loss: 261.4574
# Epoch 413/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 76.9568 - loss: 256.4593 - reconstruction_loss: 179.5025 - val_kl_loss: 77.2924 - val_loss: 333.1700 - val_reconstruction_loss: 256.4851
# Epoch 414/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 76.0844 - loss: 251.8069 - reconstruction_loss: 175.7224 - val_kl_loss: 80.9455 - val_loss: 337.0830 - val_reconstruction_loss: 256.5264
# Epoch 415/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 78.4767 - loss: 258.5712 - reconstruction_loss: 180.0945 - val_kl_loss: 80.7770 - val_loss: 347.8254 - val_reconstruction_loss: 270.4666
# Epoch 416/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 77.8675 - loss: 257.7989 - reconstruction_loss: 179.9314 - val_kl_loss: 75.9936 - val_loss: 334.8320 - val_reconstruction_loss: 258.9682
# Epoch 417/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 76.1648 - loss: 257.4060 - reconstruction_loss: 181.2411 - val_kl_loss: 77.4247 - val_loss: 342.2126 - val_reconstruction_loss: 265.4572
# Epoch 418/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 77.8871 - loss: 260.5241 - reconstruction_loss: 182.6370 - val_kl_loss: 79.0602 - val_loss: 341.2040 - val_reconstruction_loss: 263.7278
# Epoch 419/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 77.4807 - loss: 258.8689 - reconstruction_loss: 181.3882 - val_kl_loss: 77.2731 - val_loss: 335.3705 - val_reconstruction_loss: 258.0890
# Epoch 420/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 76.7019 - loss: 256.1972 - reconstruction_loss: 179.4954 - val_kl_loss: 76.7576 - val_loss: 333.6849 - val_reconstruction_loss: 257.1376
# Epoch 421/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - kl_loss: 76.1181 - loss: 254.7501 - reconstruction_loss: 178.6320 - val_kl_loss: 76.1344 - val_loss: 327.0938 - val_reconstruction_loss: 252.0438
# Epoch 422/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - kl_loss: 77.4613 - loss: 258.4650 - reconstruction_loss: 181.0038 - val_kl_loss: 76.9122 - val_loss: 338.3865 - val_reconstruction_loss: 261.6960
# Epoch 423/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 77.9186 - loss: 261.8901 - reconstruction_loss: 183.9715 - val_kl_loss: 74.8088 - val_loss: 336.0809 - val_reconstruction_loss: 262.5195
# Epoch 424/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - kl_loss: 76.6076 - loss: 256.3051 - reconstruction_loss: 179.6975 - val_kl_loss: 75.9668 - val_loss: 321.7634 - val_reconstruction_loss: 245.6880
# Epoch 425/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 78.0347 - loss: 259.0496 - reconstruction_loss: 181.0149 - val_kl_loss: 81.4100 - val_loss: 335.9425 - val_reconstruction_loss: 254.8162
# Epoch 426/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 77.3125 - loss: 257.4849 - reconstruction_loss: 180.1725 - val_kl_loss: 76.1403 - val_loss: 324.3067 - val_reconstruction_loss: 247.5507
# Epoch 427/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 75.8055 - loss: 252.1717 - reconstruction_loss: 176.3662 - val_kl_loss: 76.8808 - val_loss: 340.9530 - val_reconstruction_loss: 263.7295
# Epoch 428/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 75.5086 - loss: 252.0499 - reconstruction_loss: 176.5412 - val_kl_loss: 78.2338 - val_loss: 331.3282 - val_reconstruction_loss: 252.7826
# Epoch 429/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - kl_loss: 75.6653 - loss: 252.1144 - reconstruction_loss: 176.4492 - val_kl_loss: 79.5975 - val_loss: 334.2532 - val_reconstruction_loss: 254.5446
# Epoch 430/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 77.5006 - loss: 256.6178 - reconstruction_loss: 179.1172 - val_kl_loss: 77.7184 - val_loss: 339.0359 - val_reconstruction_loss: 261.3452
# Epoch 431/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 76.2385 - loss: 253.4465 - reconstruction_loss: 177.2080 - val_kl_loss: 75.7959 - val_loss: 338.0411 - val_reconstruction_loss: 261.5877
# Epoch 432/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 76.1148 - loss: 252.8405 - reconstruction_loss: 176.7256 - val_kl_loss: 76.6376 - val_loss: 346.0339 - val_reconstruction_loss: 270.1501
# Epoch 433/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 77.7011 - loss: 257.2245 - reconstruction_loss: 179.5235 - val_kl_loss: 75.9269 - val_loss: 337.4360 - val_reconstruction_loss: 261.9113
# Epoch 434/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 76.5932 - loss: 253.5550 - reconstruction_loss: 176.9618 - val_kl_loss: 81.5485 - val_loss: 338.2203 - val_reconstruction_loss: 256.7832
# Epoch 435/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 76.6518 - loss: 253.3192 - reconstruction_loss: 176.6674 - val_kl_loss: 76.6429 - val_loss: 334.7990 - val_reconstruction_loss: 257.5127
# Epoch 436/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 75.3425 - loss: 252.4309 - reconstruction_loss: 177.0884 - val_kl_loss: 76.0735 - val_loss: 333.6114 - val_reconstruction_loss: 259.1006
# Epoch 437/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 78.0488 - loss: 262.0970 - reconstruction_loss: 184.0483 - val_kl_loss: 78.2968 - val_loss: 345.3735 - val_reconstruction_loss: 267.0559
# Epoch 438/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - kl_loss: 77.3821 - loss: 258.5587 - reconstruction_loss: 181.1766 - val_kl_loss: 83.1368 - val_loss: 346.0153 - val_reconstruction_loss: 262.9200
# Epoch 439/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 79.3573 - loss: 260.1325 - reconstruction_loss: 180.7752 - val_kl_loss: 77.0236 - val_loss: 325.9894 - val_reconstruction_loss: 249.7635
# Epoch 440/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 77.0038 - loss: 256.2714 - reconstruction_loss: 179.2677 - val_kl_loss: 86.6207 - val_loss: 347.7497 - val_reconstruction_loss: 260.6700
# Epoch 441/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 79.6441 - loss: 260.9883 - reconstruction_loss: 181.3442 - val_kl_loss: 77.6009 - val_loss: 342.1532 - val_reconstruction_loss: 263.3516
# Epoch 442/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 78.3320 - loss: 258.4384 - reconstruction_loss: 180.1063 - val_kl_loss: 75.0584 - val_loss: 333.2527 - val_reconstruction_loss: 258.7389
# Epoch 443/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 75.4853 - loss: 250.3640 - reconstruction_loss: 174.8787 - val_kl_loss: 76.1802 - val_loss: 328.3477 - val_reconstruction_loss: 252.7633
# Epoch 444/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 76.1163 - loss: 253.2034 - reconstruction_loss: 177.0871 - val_kl_loss: 77.2573 - val_loss: 324.9443 - val_reconstruction_loss: 247.0375
# Epoch 445/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 76.6993 - loss: 254.2961 - reconstruction_loss: 177.5968 - val_kl_loss: 78.2109 - val_loss: 342.7713 - val_reconstruction_loss: 265.0113
# Epoch 446/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 76.6399 - loss: 251.6117 - reconstruction_loss: 174.9718 - val_kl_loss: 79.6805 - val_loss: 340.2304 - val_reconstruction_loss: 262.0157
# Epoch 447/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 76.4039 - loss: 253.1049 - reconstruction_loss: 176.7011 - val_kl_loss: 79.9273 - val_loss: 329.7189 - val_reconstruction_loss: 249.7392
# Epoch 448/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 78.0594 - loss: 253.6783 - reconstruction_loss: 175.6189 - val_kl_loss: 75.3637 - val_loss: 337.1217 - val_reconstruction_loss: 261.7270
# Epoch 449/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 75.2073 - loss: 252.3862 - reconstruction_loss: 177.1789 - val_kl_loss: 72.7677 - val_loss: 340.6976 - val_reconstruction_loss: 268.3863
# Epoch 450/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 75.4935 - loss: 252.7465 - reconstruction_loss: 177.2529 - val_kl_loss: 80.0519 - val_loss: 335.3034 - val_reconstruction_loss: 254.7854
# Epoch 451/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 77.0451 - loss: 254.0089 - reconstruction_loss: 176.9639 - val_kl_loss: 76.3421 - val_loss: 339.3118 - val_reconstruction_loss: 262.8381
# Epoch 452/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 76.8292 - loss: 254.8432 - reconstruction_loss: 178.0140 - val_kl_loss: 75.1363 - val_loss: 336.9554 - val_reconstruction_loss: 262.2282
# Epoch 453/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 77.1850 - loss: 254.4344 - reconstruction_loss: 177.2494 - val_kl_loss: 76.6440 - val_loss: 330.0969 - val_reconstruction_loss: 253.4924
# Epoch 454/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 75.3723 - loss: 250.5270 - reconstruction_loss: 175.1548 - val_kl_loss: 75.5221 - val_loss: 340.1880 - val_reconstruction_loss: 265.9832
# Epoch 455/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 78.0377 - loss: 260.9496 - reconstruction_loss: 182.9120 - val_kl_loss: 77.7471 - val_loss: 342.2773 - val_reconstruction_loss: 264.4127
# Epoch 456/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 76.7671 - loss: 255.8353 - reconstruction_loss: 179.0683 - val_kl_loss: 77.4324 - val_loss: 331.2793 - val_reconstruction_loss: 254.4390
# Epoch 457/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - kl_loss: 76.7982 - loss: 251.2794 - reconstruction_loss: 174.4812 - val_kl_loss: 74.6524 - val_loss: 339.0877 - val_reconstruction_loss: 265.4095
# Epoch 458/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 76.9978 - loss: 255.7929 - reconstruction_loss: 178.7951 - val_kl_loss: 79.4094 - val_loss: 329.5136 - val_reconstruction_loss: 250.7008
# Epoch 459/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 75.9731 - loss: 251.9507 - reconstruction_loss: 175.9776 - val_kl_loss: 77.7094 - val_loss: 330.1094 - val_reconstruction_loss: 252.1456
# Epoch 460/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 76.0966 - loss: 251.4342 - reconstruction_loss: 175.3377 - val_kl_loss: 78.7112 - val_loss: 343.2991 - val_reconstruction_loss: 263.9110
# Epoch 461/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 76.4418 - loss: 252.5544 - reconstruction_loss: 176.1126 - val_kl_loss: 77.9422 - val_loss: 333.5242 - val_reconstruction_loss: 255.2264
# Epoch 462/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 76.2682 - loss: 253.3858 - reconstruction_loss: 177.1176 - val_kl_loss: 76.6641 - val_loss: 338.7307 - val_reconstruction_loss: 264.0735
# Epoch 463/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 75.3583 - loss: 252.1146 - reconstruction_loss: 176.7563 - val_kl_loss: 75.8275 - val_loss: 328.3216 - val_reconstruction_loss: 252.6611
# Epoch 464/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 75.4528 - loss: 250.0021 - reconstruction_loss: 174.5493 - val_kl_loss: 77.3366 - val_loss: 329.0755 - val_reconstruction_loss: 253.4576
# Epoch 465/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 76.6049 - loss: 253.6553 - reconstruction_loss: 177.0505 - val_kl_loss: 78.7467 - val_loss: 337.0865 - val_reconstruction_loss: 258.7589
# Epoch 466/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 77.2670 - loss: 252.8671 - reconstruction_loss: 175.6002 - val_kl_loss: 76.8520 - val_loss: 333.1113 - val_reconstruction_loss: 255.2524
# Epoch 467/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 78.0164 - loss: 254.0938 - reconstruction_loss: 176.0774 - val_kl_loss: 77.3630 - val_loss: 327.4586 - val_reconstruction_loss: 250.4061
# Epoch 468/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 76.1082 - loss: 253.0193 - reconstruction_loss: 176.9111 - val_kl_loss: 76.2495 - val_loss: 336.3047 - val_reconstruction_loss: 260.7548
# Epoch 469/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 75.7881 - loss: 252.5106 - reconstruction_loss: 176.7225 - val_kl_loss: 80.4299 - val_loss: 342.3008 - val_reconstruction_loss: 261.4617
# Epoch 470/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 77.4812 - loss: 254.9357 - reconstruction_loss: 177.4545 - val_kl_loss: 75.5371 - val_loss: 329.7226 - val_reconstruction_loss: 254.2694
# Epoch 471/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - kl_loss: 75.7408 - loss: 251.5863 - reconstruction_loss: 175.8455 - val_kl_loss: 76.7301 - val_loss: 339.1773 - val_reconstruction_loss: 262.0999
# Epoch 472/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 75.6779 - loss: 252.9742 - reconstruction_loss: 177.2964 - val_kl_loss: 82.7761 - val_loss: 332.7307 - val_reconstruction_loss: 249.0840
# Epoch 473/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 78.0685 - loss: 254.8749 - reconstruction_loss: 176.8064 - val_kl_loss: 76.7028 - val_loss: 329.4691 - val_reconstruction_loss: 252.2839
# Epoch 474/1000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - kl_loss: 76.4107 - loss: 250.9783 - reconstruction_loss: 174.5676 - val_kl_loss: 75.2076 - val_loss: 332.2624 - val_reconstruction_loss: 256.7441
# Epoch 474: early stopping
# Restoring model weights from the end of the best epoch: 424.

# %%
# save the model
model.save(f"bvae_model_ldims_{latent_dims}.keras")

# %%
import matplotlib.pyplot as plt
# Select a few images from the test dataset to reconstruct
num_images_to_reconstruct = 5

# Take a batch from the test dataset
for test_batch in test_ds.take(1):
    # Select the first `num_images_to_reconstruct` images from the batch
    original_images = test_batch[:num_images_to_reconstruct]

# Get the reconstructed images from the model
# Ensure the model is built by passing a sample input
model.predict(original_images[:1])
reconstructed_images, _, _ = model(original_images)


# Plot the original and reconstructed images side by side
plt.figure(figsize=(10, 4))
for i in range(num_images_to_reconstruct):
    # Plot original image
    plt.subplot(2, num_images_to_reconstruct, i + 1)
    plt.imshow(tf.squeeze(original_images[i]).numpy(), cmap='gray')
    plt.title("Original")
    plt.axis('off')

    # Plot reconstructed image
    plt.subplot(2, num_images_to_reconstruct, i + 1 + num_images_to_reconstruct)
    plt.imshow(tf.squeeze(reconstructed_images[i]).numpy(), cmap='gray')
    plt.title("Reconstructed")
    plt.axis('off')

plt.suptitle('Original vs Reconstructed Images')
plt.tight_layout(rect=[0, 0.03, 1, 0.95]) # Adjust layout to prevent overlap of title
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %%
import matplotlib.pyplot as plt
# Select a few images from the test dataset to reconstruct
num_images_to_reconstruct = 1

# Take a batch from the test dataset
for test_batch in test_ds.take(1):
    # Select the first `num_images_to_reconstruct` images from the batch
    to_encode_images = test_batch[:num_images_to_reconstruct]
to_encode_images
# Out:
# <tf.Tensor: shape=(1, 128, 128, 1), dtype=float32, numpy=
# array([[[[255.],
#          [255.],
#          [255.],
#          ...,
#          [255.],
#          [255.],
#          [255.]],
#
#         [[255.],
#          [255.],
#          [255.],
#          ...,
#          [255.],
#          [255.],
#          [255.]],
#
#         [[255.],
#          [255.],
#          [255.],
#          ...,
#          [255.],
#          [255.],
#          [255.]],
#
#         ...,
#
#         [[255.],
#          [255.],
#          [255.],
#          ...,
#          [255.],
#          [255.],
#          [255.]],
#
#         [[255.],
#          [255.],
#          [255.],
#          ...,
#          [255.],
#          [255.],
#          [255.]],
#
#         [[255.],
#          [255.],
#          [255.],
#          ...,
#          [255.],
#          [255.],
#          [255.]]]], dtype=float32)>

# %%
encoded_images = model.encode(to_encode_images)
mu, log, sigma, recon = encoded_images

mu, log, sigma
# Out:
# (<tf.Tensor: shape=(1, 8), dtype=float32, numpy=
#  array([[ 1.2182456 ,  1.4842016 ,  0.6609768 , -1.1881143 ,  0.27913707,
#          -1.2593757 ,  0.52986073,  0.9295238 ]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 8), dtype=float32, numpy=
#  array([[-5.965605 , -5.642002 , -4.4742484, -5.200336 , -4.5951676,
#          -6.2990556, -4.2613244, -4.893192 ]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 8), dtype=float32, numpy=
#  array([[0.05065069, 0.0595463 , 0.1067651 , 0.0742611 , 0.10050137,
#          0.04287237, 0.11875863, 0.08658784]], dtype=float32)>)

# %%
# prompt: create image using the model and move in the latent dimension to show the change in all directions. starting image should be a random image from the latent dimension

import matplotlib.pyplot as plt
import numpy as np
# Function to generate images by moving along a latent dimension
def generate_images_along_latent(model, start_latent_vector, latent_dim_index, steps=10, span=3.0):
    """
    Generates images by varying the value of a specific latent dimension.

    Args:
        model: The trained BVAE model.
        start_latent_vector: The starting point in the latent space (a numpy array).
        latent_dim_index: The index of the latent dimension to vary.
        steps: The number of steps to take along the dimension.
        span: The range to vary the latent dimension value (from -span to +span).

    Returns:
        A list of generated images.
    """
    images = []
    # Create a range of values for the chosen latent dimension
    latent_values = np.linspace(-span, span, steps)

    for value in latent_values:
        # Create a new latent vector by modifying the chosen dimension
        current_latent_vector = np.copy(start_latent_vector)
        current_latent_vector[latent_dim_index] = value

        # Ensure the latent vector has the correct batch dimension for prediction
        current_latent_vector_batch = np.expand_dims(current_latent_vector, axis=0)

        # Decode the latent vector to an image
        generated_image = model.decode(current_latent_vector_batch)

        # Append the image to the list
        images.append(tf.squeeze(generated_image).numpy())

    return images

# Get the latent dimension size from the model
latent_dims = model.latent_dims

# Generate a random latent vector as the starting point
random_latent_vector = np.random.normal(size=(latent_dims,))

# Iterate through each latent dimension and generate images
for dim_index in range(min(latent_dims, 20)):
    print(f"Generating images by varying latent dimension {dim_index}")
    generated_images = generate_images_along_latent(
        model,
        random_latent_vector,
        dim_index,
        steps=10,  # Number of images to generate for this dimension
        span=3.0   # Range of variation in the latent dimension
    )

    # Plot the generated images for the current dimension
    plt.figure(figsize=(len(generated_images) * 2, 2))
    for i, img in enumerate(generated_images):
        plt.subplot(1, len(generated_images), i + 1)
        plt.imshow(img, cmap='gray')
        plt.axis('off')
    plt.suptitle(f'Varying Latent Dimension {dim_index}')
    plt.show()
